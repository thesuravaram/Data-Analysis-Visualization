# %% [markdown]
# <a href="https://colab.research.google.com/github/thesuravaram/Data-Analysis-Visualization/blob/main/L4_LinearRegressionModels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#Sample DATASET
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
Y = np.array([50, 55, 65, 70, 80])

# %%
#Model

model =LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
#Predictions
Y_Pred = model.predict(X)

# %%
#Equation

print("Intercept: ", model.intercept_)
print("Slope: ", model.coef_[0])
# Out:
# Intercept:  41.5
# Slope:  7.500000000000001

# %%
#Visualization

plt.scatter(X, Y, color="blue", label="Actual Data")
plt.plot(X, Y_Pred, color='red', label="Regression Line")
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.title("Linear Regression")
plt.legend()
plt.show()

# %% [markdown]
# **Multiple Linear** **Regression**

# %%
import pandas as pd

# %%
#Dataset

data = {
    "StudyHours": [2, 3, 4, 5, 6],
    "SleepHours": [8, 7, 6, 7, 8],
    "Score": [55, 65, 70, 80, 85]
}

# %%
df = pd.DataFrame(data)

# %%
X = df[["StudyHours", "SleepHours"]]
Y = df["Score"]

#Model
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
#predictions
Y_Pred  = model.predict(X)

# %%
#Coefficients
print("Intercept: ", model.intercept_)
print("Coefficients: ", model.coef_)
# Out:
# Intercept:  43.57142857142856
# Coefficients:  [ 7.5        -0.35714286]

# %%
#Compare Actual Vs Predicted

results = pd.DataFrame({"Actual": Y, "Predicted": Y_Pred})
print(results)
# Out:
#    Actual  Predicted
# 0      55  55.714286
# 1      65  63.571429
# 2      70  71.428571
# 3      80  78.571429
# 4      85  85.714286
